# %%
import LoadVisualize as load

attr = load.loadDataset('Hierarchical_2.csv')
load.visualizeScatter(attr)

# %%
import dissimilarityMeasure as dis

a, b = dis.singleLinkMIN(attr[0], attr[1])
